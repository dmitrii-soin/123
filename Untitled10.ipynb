# %% [markdown]
# <a href="https://colab.research.google.com/github/dmitrii-soin/123/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv("world_real.csv") #данные по продажам кваритир
data
# Out:
#                                                     title   country  \
# 0       2 room apartment 120 m² in Mediterranean Regio...    Turkey
# 1                   4 room villa 500 m² in Kalkan, Turkey    Turkey
# 2               1 room apartment 65 m² in Antalya, Turkey    Turkey
# 3                  1 room apartment  in Pattaya, Thailand  Thailand
# 4                  2 room apartment  in Pattaya, Thailand  Thailand
# ...                                                   ...       ...
# 147531        5 room apartment 310 m² in Gazipasa, Turkey    Turkey
# 147532  4 room apartment 192 m² in Marmara Region, Turkey    Turkey
# 147533        2 room apartment  in Marmara Region, Turkey    Turkey
# 147534                       Apartment  in Akarca, Turkey    Turkey
# 147535                 4 room apartment 140 m² in, Turkey    Turkey
#
#                                          location  building_construction_year  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147536 entries, 0 to 147535
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   title                       147536 non-null  object
#  1   country                     147406 non-null  object
#  2   location                    147405 non-null  object
#  3   building_construction_year  64719 non-null   float64
#  4   building_total_floors       68224 non-null   float64
#  5   apartment_floor             54592 non-null   float64
#  6   apartment_rooms             74178 non-null   float64
#  7   apartment_bedrooms          36982 non-null   float64
#  8   apartment_bathrooms         55973 non-null   float64
#  9   apartment_total_area        141796 non-null  object
#  10  apartment_living_area       27712 non-null   object
#  11  price_in_USD                144961 non-null  float64
# ...

# %%
del data["image"] #удаление ненужных столбцов
del data["url"] #удаление ненужных столбцов

# %%
del data["apartment_living_area"] #слишком мало значений

# %%
data1 = data.dropna(subset=['country','location','price_in_USD', 'apartment_total_area'])
 # удаление пропусков по столбцам с наименьшим количесвом пропусков

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140126 entries, 0 to 147535
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   title                       140126 non-null  object
#  1   country                     140126 non-null  object
#  2   location                    140126 non-null  object
#  3   building_construction_year  62222 non-null   float64
#  4   building_total_floors       66655 non-null   float64
#  5   apartment_floor             53643 non-null   float64
#  6   apartment_rooms             72634 non-null   float64
#  7   apartment_bedrooms          35156 non-null   float64
#  8   apartment_bathrooms         54472 non-null   float64
#  9   apartment_total_area        140126 non-null  object
#  10  price_in_USD                140126 non-null  float64
# dtypes: float64(7), object(4)
# memory usage: 12.8+ MB

# %%
data1['apartment_total_area'] = data1['apartment_total_area'].str.extract('(\d+)', expand=True).astype(int)
# таким образом удалям m2 из столбца с площадью помещения и преобразуем его в числовой формат

# %%
data1
# Out:
#                                                     title  country  \
# 0       2 room apartment 120 m² in Mediterranean Regio...   Turkey
# 1                   4 room villa 500 m² in Kalkan, Turkey   Turkey
# 2               1 room apartment 65 m² in Antalya, Turkey   Turkey
# 5               1 room apartment 28 m² in Batumi, Georgia  Georgia
# 6             4 room apartment 245 m² in Yesiloez, Turkey   Turkey
# ...                                                   ...      ...
# 147529         3 room apartment 106 m² in Yaylali, Turkey   Turkey
# 147530  3 room apartment 168 m² in Bahcelievler Mahall...   Turkey
# 147531        5 room apartment 310 m² in Gazipasa, Turkey   Turkey
# 147532  4 room apartment 192 m² in Marmara Region, Turkey   Turkey
# 147535                 4 room apartment 140 m² in, Turkey   Turkey
#
#                                               location  \
# 0                         Mediterranean Region, Turkey
# ...

# %%
data1.describe() #работа с выбросами
# Out:
#        building_construction_year  building_total_floors  apartment_floor  \
# count                62222.000000           66655.000000     53643.000000
# mean                  1996.319003               8.597525         5.787931
# std                    160.176653               8.318215         5.523481
# min                      1.000000              -1.000000        -2.000000
# 25%                   2003.000000               2.000000         2.000000
# 50%                   2021.000000               5.000000         4.000000
# 75%                   2024.000000              14.000000         8.000000
# max                   2316.000000             124.000000       202.000000
#
#        apartment_rooms  apartment_bedrooms  apartment_bathrooms  \
# count     72634.000000        35156.000000         54472.000000
# mean          2.569995            2.306093             1.359028
# std           1.296229           18.743860             0.742516
# ...

# %%
data1["building_construction_year"].value_counts()
# Out:
# 2023.0    8541
# 2025.0    8424
# 2024.0    5731
# 2026.0    4465
# 2022.0    3531
#           ...
# 1856.0       1
# 1877.0       1
# 1882.0       1
# 1853.0       1
# 202.0        1
# Name: building_construction_year, Length: 224, dtype: int64

# %%
data1.loc[data1['building_construction_year'] >2030]
#год постройки дома, много значений 2024-2030, видимо, предполагаемый год сдачи, а 2316 тут явные ошибки
# Out:
#                                               title  country  \
# 42033  House 2 bathrooms 140 m² in Toekoel, Hungary  Hungary
#
#                                                 location  \
# 42033  Toekoel, Central Hungary, Szigetszentmiklosi j...
#
#        building_construction_year  building_total_floors  apartment_floor  \
# 42033                      2316.0                    2.0              NaN
#
#        apartment_rooms  apartment_bedrooms  apartment_bathrooms  \
# 42033              NaN                 NaN                  NaN
#
#        apartment_total_area  price_in_USD
# 42033                   140      136092.0

# %%
data1.drop(42033, axis=0, inplace=True)

# %%
data1.loc[data1['apartment_floor'] > 100] #этаж квартиры, тут явные ошибки
# Out:
#                                                    title     country  \
# 27729   Penthouse 3 bedrooms 105 m² in Tivat, Montenegro  Montenegro
# 132761             1 room apartment 517 m² in Dubai, UAE         UAE
#
#                                      location  building_construction_year  \
# 27729   Tivat, Tivat Municipality, Montenegro                      2022.0
# 132761                             Dubai, UAE                         NaN
#
#         building_total_floors  apartment_floor  apartment_rooms  \
# 27729                     3.0            105.0              NaN
# 132761                    2.0            202.0              4.0
#
#         apartment_bedrooms  apartment_bathrooms  apartment_total_area  \
# 27729                  3.0                  2.0                   105
# 132761                 1.0                  2.0                   517
#
#         price_in_USD
# 27729       400451.0
# 132761      168983.0

# %%
data1.drop(27729, axis=0, inplace=True)
data1.drop(132761, axis=0, inplace=True)

# %%
data1.loc[data1['apartment_rooms'] > 30] #количество комнат больше 100 ошибка
# Out:
#                                                     title  country  \
# 106273  3 room apartment 134 m² in Guardamar del Segur...    Spain
# 114898         9 room apartment 161 m² in Zagreb, Croatia  Croatia
# 116090          9 room apartment 4 661 m² in Riga, Latvia   Latvia
# 116643         9 room apartment 130 m² in Zagreb, Croatia  Croatia
# 117768         2 room apartment 57 m² in Tbilisi, Georgia  Georgia
# 142333             9 room apartment 90 m² in Terni, Italy    Italy
# 142556            9 room apartment 100 m² in Terni, Italy    Italy
#
#                                                  location  \
# 106273  Guardamar del Segura, Valencian Community, el ...
# 114898                                    Zagreb, Croatia
# 116090                              Vidzeme, Riga, Latvia
# 116643                                    Zagreb, Croatia
# 117768                         Abkhazia, Tbilisi, Georgia
# 142333                               Umbria, Terni, Italy
# ...

# %%
data1.drop(116090, axis=0, inplace=True)
data1.drop(117768, axis=0, inplace=True)
data1.drop(142556, axis=0, inplace=True)
data1.drop(106273, axis=0, inplace=True)
data1.drop(114898, axis=0, inplace=True)
data1.drop(116643, axis=0, inplace=True)
data1.drop(142333, axis=0, inplace=True)

# %%
data1.loc[data1['apartment_bedrooms'] > 30] #количество спален больше 100 ошибка
# Out:
#                                                     title     country  \
# 4350    9 room apartment 440 m² in Bahcelievler Mahall...      Turkey
# 4487    9 room apartment 242 m² in Bahcelievler Mahall...      Turkey
# 4639    9 room apartment 226 m² in Bahcelievler Mahall...      Turkey
# 9033    9 room apartment 166 m² in Bahcelievler Mahall...      Turkey
# 20854    9 room apartment 88 m² in Montenegro, Montenegro  Montenegro
# 28866            9 room apartment 90 m² in Greece, Greece      Greece
# 31870           9 room apartment 120 m² in Greece, Greece      Greece
# 95192        9 room apartment 2 000 m² in Alicante, Spain       Spain
# 109841  9 room apartment 2 400 m² in Castell-Platja d ...       Spain
# 138180  9 room apartment 1 300 m² in Castell-Platja d ...       Spain
# 144030           9 room apartment 95 m² in Greece, Greece      Greece
#
#                                                  location  \
# 4350       Bahcelievler Mahallesi, Marmara Region, Turkey
# ...

# %%
data1.drop(20854, axis=0, inplace=True)
data1.drop(28866, axis=0, inplace=True)
data1.drop(31870, axis=0, inplace=True)
data1.drop(144030, axis=0, inplace=True)
data1.drop(4350, axis=0, inplace=True)
data1.drop(4487, axis=0, inplace=True)
data1.drop(4639, axis=0, inplace=True)
data1.drop(9033, axis=0, inplace=True)
data1.drop(109841, axis=0, inplace=True)
data1.drop(138180, axis=0, inplace=True)

# %%
data1.loc[data1['apartment_bathrooms'] > 40] #количество ванных комнат больше 100 ошибка
# Out:
#                                               title country  \
# 95192  9 room apartment 2 000 m² in Alicante, Spain   Spain
#
#                                                 location  \
# 95192  Valencian Community, Alicante, Provincia de Al...
#
#        building_construction_year  building_total_floors  apartment_floor  \
# 95192                         NaN                    NaN              3.0
#
#        apartment_rooms  apartment_bedrooms  apartment_bathrooms  \
# 95192              NaN                43.0                 43.0
#
#        apartment_total_area  price_in_USD
# 95192                     2     2403423.0

# %%
data1.drop(95192, axis=0, inplace=True)

# %%
data1.loc[data1['apartment_total_area'] <= 1] #сомнительные значения площадей помещений
# Out:
#                                                     title  country  \
# 1122       2 room apartment 1 000 m² in Konyaalti, Turkey   Turkey
# 2712          2 room apartment 1 200 m² in Alanya, Turkey   Turkey
# 4304    6 room apartment 1 424 m² in Bahcelievler Maha...   Turkey
# 4544    7 room apartment 1 128 m² in Bahcelievler Maha...   Turkey
# 4611    6 room apartment 1 000 m² in Bahcelievler Maha...   Turkey
# ...                                                   ...      ...
# 147018           6 room house 1 342 m² in Zagreb, Croatia  Croatia
# 147095            3 room villa 1 400 m² in Porec, Croatia  Croatia
# 147161       House 1 329 m² in Brezovec Zelinski, Croatia  Croatia
# 147226      2 room villa 1 850 m² in Opcina Bale, Croatia  Croatia
# 147320  Mansion 3 bedrooms 1 280 m² in Opcina Svetvinc...  Croatia
#
#                                                  location  \
# 1122     Konyaalti, Mediterranean Region, Antalya, Turkey
# ...

# %%
data2 = data1.loc[data1['apartment_total_area'] > 1] #удаление сточек со значением площади помещений в 1 м2

# %%
data2.describe()
# Out:
#        building_construction_year  building_total_floors  apartment_floor  \
# count                62087.000000           66496.000000     53598.000000
# mean                  1996.330037               8.605285         5.783350
# std                    160.316867               8.301200         5.430007
# min                      1.000000              -1.000000        -2.000000
# 25%                   2003.000000               2.000000         2.000000
# 50%                   2021.000000               5.000000         4.000000
# 75%                   2024.000000              14.000000         8.000000
# max                   2028.000000             124.000000        82.000000
#
#        apartment_rooms  apartment_bedrooms  apartment_bathrooms  \
# count     72547.000000        35097.000000         54387.000000
# mean          2.563290            2.107958             1.354846
# std           1.138907            1.039399             0.700521
# ...

# %%
data2.info() # итоговая таблица для анализа, по столбцам 3-8 слишком много пропущенных значений для удаления или замены
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139501 entries, 0 to 147535
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   title                       139501 non-null  object
#  1   country                     139501 non-null  object
#  2   location                    139501 non-null  object
#  3   building_construction_year  62087 non-null   float64
#  4   building_total_floors       66496 non-null   float64
#  5   apartment_floor             53598 non-null   float64
#  6   apartment_rooms             72547 non-null   float64
#  7   apartment_bedrooms          35097 non-null   float64
#  8   apartment_bathrooms         54387 non-null   float64
#  9   apartment_total_area        139501 non-null  int64
#  10  price_in_USD                139501 non-null  float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 12.8+ MB

# %%
data2.groupby("country")["apartment_total_area"].mean().sort_values() #средняя площадь помещений по странам
# Out:
# country
# Serbia              54.461538
# Russia              63.652794
# Czech Republic      67.480000
# Georgia             67.843606
# Uzbekistan          72.347737
# Thailand            82.470746
# Belarus             82.647918
# Northern Cyprus     87.413462
# Cyprus              89.385714
# Poland              92.807980
# Armenia             94.645455
# Finland             95.805519
# Indonesia           96.030303
# Austria            107.959184
# Lithuania          108.061273
# Hungary            114.462388
# Australia          120.000000
# Turkey             129.995988
# UAE                164.085056
# Montenegro         165.918606
# Spain              167.540579
# Latvia             171.588681
# Croatia            178.615003
# Portugal           182.222703
# Greece             199.965544
# Italy              236.042086
# United States      250.436090
# Name: apartment_total_area, dtype: float64

# %%
data2.groupby(["country", "apartment_rooms"])["price_in_USD"].mean().sort_values()
#группировка по странам, комнатам и средней цене на квартиры, с форматаом отображения цены я так и не понял, что делать
# Out:
# country    apartment_rooms
# Lithuania  7.0                1.630400e+04
# Russia     8.0                1.834000e+04
#            9.0                4.087200e+04
# Belarus    1.0                4.541022e+04
# Georgia    1.0                5.063471e+04
#                                   ...
# UAE        5.0                4.455432e+06
#            7.0                4.939156e+06
#            6.0                5.548234e+06
#            9.0                5.857812e+06
#            8.0                1.140641e+07
# Name: price_in_USD, Length: 223, dtype: float64
