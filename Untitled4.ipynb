# %% [markdown]
# <a href="https://colab.research.google.com/github/dmitrii-soin/123/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_csv("MoviesTopRated.csv")
# Out:
#       Unnamed: 0      id        genre_ids                           title  \
# 0              0     238         [18, 80]                   The Godfather
# 1              1     278         [18, 80]        The Shawshank Redemption
# 2              2     240         [18, 80]           The Godfather Part II
# 3              3     424  [18, 36, 10752]                Schindler's List
# 4              4   19404  [35, 18, 10749]     Dilwale Dulhania Le Jayenge
# ...          ...     ...              ...                             ...
# 9995        9995  604563     [35, 12, 28]  OSS 117: From Africa with Love
# 9996        9996  193687        [878, 18]                 Z for Zachariah
# 9997        9997   14423         [35, 28]                    First Sunday
# 9998        9998   10154  [35, 80, 10749]                Mickey Blue Eyes
# 9999        9999  440762             [35]       Jay and Silent Bob Reboot
#
#                                                overview  popularity  \
# ...

# %%
movies = pd.read_csv("MoviesTopRated.csv")

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    10000 non-null  int64
#  1   id            10000 non-null  int64
#  2   genre_ids     10000 non-null  object
#  3   title         10000 non-null  object
#  4   overview      9998 non-null   object
#  5   popularity    10000 non-null  float64
#  6   release_date  10000 non-null  object
#  7   vote_average  10000 non-null  float64
#  8   vote_count    10000 non-null  int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 703.2+ KB

# %%
movies.describe()
# Out:
#         Unnamed: 0            id    popularity  vote_average    vote_count
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    4999.50000  1.848149e+05     21.545916      6.771740   1673.664300
# std     2886.89568  2.416694e+05     76.294319      0.637059   2890.121954
# min        0.00000  2.000000e+00      0.600000      5.700000    200.000000
# 25%     2499.75000  1.033975e+04      9.118000      6.300000    322.000000
# 50%     4999.50000  3.540850e+04     12.440500      6.700000    611.000000
# 75%     7499.25000  3.476268e+05     19.556500      7.200000   1588.250000
# max     9999.00000  1.140066e+06   4696.546000      8.700000  34262.000000

# %%
movies.loc[movies.isnull()["overview"] == True]  #пустые ячейки
# Out:
#       Unnamed: 0      id genre_ids                    title overview  \
# 7195        7195  919952      [35]         Il grande giorno      NaN
# 9508        9508   57114      [35]  Amore, bugie e calcetto      NaN
#
#       popularity release_date  vote_average  vote_count
# 7195       5.825   2022-12-22           6.3         236
# 9508       4.784   2008-04-04           5.8         208

# %%
movies.corr() [["popularity",	"vote_average",	"vote_count"]] #корреляция по основным столбцам
# Out:
# <ipython-input-178-d7b66228db05>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   movies.corr() [["popularity",	"vote_average",	"vote_count"]] #корреляция по основным столбцам
#               popularity  vote_average  vote_count
# Unnamed: 0     -0.083754     -0.989250   -0.233170
# id              0.132321      0.011729   -0.083221
# popularity      1.000000      0.092418    0.140166
# vote_average    0.092418      1.000000    0.259226
# vote_count      0.140166      0.259226    1.000000

# %% [markdown]
# корреляция по основным столбам практически отсутвует

# %%
movies1 = movies.loc[0:99] #создание выбоки из 100 первых строчек таблицы

# %%
movies1.sum()[["popularity","vote_average","vote_count"]] #сумма
# Out:
# popularity      8418.869
# vote_average       838.4
# vote_count        765192
# dtype: object

# %%
movies1.mean()[["popularity","vote_average","vote_count"]] #среднее по столбцу
# Out:
# <ipython-input-181-7b252d03ba7d>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   movies1.mean()[["popularity","vote_average","vote_count"]] #среднее по столбцу
# popularity        84.18869
# vote_average       8.38400
# vote_count      7651.92000
# dtype: float64

# %%
movies1.median()[["popularity","vote_average","vote_count"]] #медиана по столбцу
# Out:
# <ipython-input-182-673168c8de8d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   movies1.median()[["popularity","vote_average","vote_count"]] #медиана по столбцу
# popularity        30.64
# vote_average       8.40
# vote_count      3881.00
# dtype: float64

# %%
movies1.std()[["popularity","vote_average","vote_count"]] #ст.отклонение по столбцу
# Out:
# <ipython-input-183-c46f4631d71f>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   movies1.std()[["popularity","vote_average","vote_count"]] #ст.отклонение по столбцу
# popularity       266.753967
# vote_average       0.095049
# vote_count      8512.547900
# dtype: float64

# %%
movies1["popularity"]>30
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99     True
# Name: popularity, Length: 100, dtype: bool

# %%
movies1[["vote_average"]>6 & ["vote_average"]<9]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-191-30b8eb86f273> in <cell line: 1>()
# ----> 1 movies1[["vote_average"]>6 & ["vote_average"]<9]
#
# TypeError: unsupported operand type(s) for &: 'int' and 'list'
